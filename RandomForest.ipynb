# %% [markdown]
# <a href="https://colab.research.google.com/github/Muthoni-Kamotho/Random-Forest-Classifiers/blob/main/RandomForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install Streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 35.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np

dataframe1 = pd.read_csv('/content/Iris_Data.csv.xls')
dataframe1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# mapping the target column to numeric values for model training
dataframe1['species'] = dataframe1['species'].map({'Iris-setosa': 1, 'Iris-versicolor': 2, 'Iris-virginica': 3})

# %%
A = dataframe1.iloc[:, :-1]
B = dataframe1.iloc[:, -1]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(A, b, test_size=0.3, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
import pickle
with open("classifier1.pkl", "wb") as file:
    pickle.dump(model, file)

# %%
import pandas as pd
import numpy as np
import pickle
import streamlit as st

with open('classifier1.pkl', 'rb') as file:
    classifier1 = pickle.load(file)

def prediction1(sepal_length, sepal_width, petal_length, petal_width):
    prediction = classifier1.predict([[sepal_length, sepal_width, petal_length, petal_width]])
    return prediction

def main():
    st.title("Iris Flower Prediction")

    html_temp = """

    Streamlit Iris Flower Classifier ML App

    """

    st.markdown(html_temp, unsafe_allow_html=True)

    sepal_length = st.text_input("Sepal Length", "Type Here")
    sepal_width = st.text_input("Sepal Width", "Type Here")
    petal_length = st.text_input("Petal Length", "Type Here")
    petal_width = st.text_input("Petal Width", "Type Here")
    result = ""

    if st.button("Predict"):
        try:
            sepal_length = float(sepal_length)
            sepal_width = float(sepal_width)
            petal_length = float(petal_length)
            petal_width = float(petal_width)
            result = prediction1(sepal_length, sepal_width, petal_length, petal_width)
            st.write('The predicted class is', result[0])
        except ValueError:
            st.error("Please enter valid numeric values.")

if __name__ == '__main__':
    main()
# Out:
# 2024-07-23 17:12:28.964
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2024-07-23 17:12:28.973 Session state does not function when running a script without `streamlit run`

# %%
! streamlit run /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.196.146.161:8501
#
#   Stopping...
# ^C
